# %% [markdown]
# <a id="third_sprint"></a>
# # спринт №
#
#
# ## оглавление
# <a id="title"></a>
#
# * [Теория](#theory)
#     * [Вернёмся к алгоритмическим собеседованиям](#theory_1)
#     * [Полезные источники](#theory_2)
#     * [На собеседовании](theory_3)
# * [Задачи для подготовки](#tasks)
#     * [x] [А. Card Counter](#A)
#     * [B. ](#B)
#     * [C. ](#C)
#     * [D. ](#D)
#     * [E. ](#E)
#     * [F. ](#F)
#     * [G. ](#G)
#     * [H. ](#H)
#     * [I. ](#I)
#     * [J. ](#J)
#     * [K. ](#K)
#     * [L. ](#L)

# %% [markdown]
# <a id="theory"></a>
#
# ## Theory

# %% [markdown]
# ### Вернёмся к алгоритмическим собеседованиям
# Больше задач богу задач!
# В первом спринте мы рассказывали, как решать алгоритмические задачи и проходить алгоритмические собеседования. С тех пор вы проделали большой путь и изучили почти все нужные для этого алгоритмы и структуры данных. Самое время потренироваться применять полученные знания на практике!
# До сих пор задачи, которые вы встречали по ходу курса, относились к теме спринта. То есть в отличие от реального собеседования, мы не предлагали вам выбрать правильный алгоритм или структуру данных. Чтобы исправить этот недостаток, мы подготовили для вас небольшой набор с задачами с собеседований на разные темы.
# Если вы планируете тренироваться или готовиться к собеседованиям, начните именно с него. Он совсем небольшой, зато там представлены почти все темы, встречающиеся на алгоритмическом собеседовании. Задачи, которые вы сможете решить, покажут вам темы, изученные неплохо. Остальные темы нужно будет повторить, периодически возвращаясь к этим задачам.
# ❗ Задачи с алгоритмических собеседований — дополнительная возможность для вас потренироваться. Чтобы успешно закончить курс и получить диплом, решать их необязательно.
# Ещё одно отличие этого набора задач от всех предыдущих — закрытые тесты. Вы увидите только тесты из условия, по остальным будет вердикт: OK или указание на ошибку в каком-то тесте. Мы делаем это сознательно: чтобы вы также потренировались составлять тесты для своего решения.
# Насколько быстро нужно решать такие задачи?
# Требуемое время решения тренировочных задач сильно зависит от самой задачи и ваших целей. В общем случае оно должно составлять примерно половину длительности интервью в компанию, куда вы будете собеседоваться.
# Есть несколько причин, почему решать тренировочные задачи чуть проще, чем задачи на собеседовании.
#
#     На собеседовании вам нужно будет уточнить параметры задачи, входных данных и ограничения, а в Яндекс.Контесте это будет написано явно в условии.
#     В этих задачах у вас сразу будет тест из условия.
#     Решая задачи из набора, вы можете не проговаривать решение вслух.
#     В этих задачах вы увидите тип ошибки.
#     Наконец, вы просто будете меньше волноваться, чем на реальном собеседовании.
#
# В то же время есть несколько замедляющих факторов:
#
#     На собеседовании интервьюер может дать вам подсказку при необходимости.
#     Из-за особенностей Яндекс.Контеста вам нужно будет реализовать ввод-вывод.
#     Некоторые из предложенных задач, особенно в конце набора, немного сложнее «средних» задач с собеседований. Вполне возможно, что подобная задача вам попадётся. Но так как задач на собеседовании обычно две, вторая должна быть немного проще.
#
# Хотя это и тренировочный формат, мы настоятельно рекомендуем решать задачи, как будто вы находитесь на собеседовании:
#
#     На одну задачу выделите хотя бы полчаса, чтобы вас ничего не отвлекало.
#     Если решение не приходит в голову — не отчаивайтесь, потратьте эти полчаса на придумывание. Не нужно спустя пять минут искать решение в интернете — так вы не научитесь придумывать решения.
#     При написании кода не используйте средства разработки. На собеседовании у вас не будет возможности запускать код и пользоваться отладчиком, поэтому и в тренировке работайте только в простом текстовом редакторе. В случае вердикта не OK старайтесь найти ошибку, читая код, и не применяйте отладчик.
#
# 💡 Эти задачи придумали не мы. Иначе они были бы не с собеседований, а значит, толку от них было бы мало. Идеи решения можно найти в интернете. Мы могли добавить подсказки в выпадающие элементы, но решили этого не делать, так как был бы большой соблазн посмотреть подсказку сразу же после возникновения трудностей.
# В следующем уроке мы предложим полезные внешние источники для самоподготовки.

# %% [markdown]
# ### Полезные источники
# Мы стараемся давать всё необходимое и добавляем новый материал. При этом надеемся, что ваша алгоритмическая практика не закончится с нашим курсом.
# Предлагаем вам ресурсы для самостоятельного изучения. В основном они на английском, но есть и материалы, переведённые на русский язык.
# image
# Самое необходимое
# Скорее всего, эти ресурсы вы знаете, но для порядка перечислим их.
#
#     LeetCode — самый большой банк задач с собеседований. Любая задача, которая когда-либо задавалась на алгоритмическом собеседовании, наверняка есть тут. Задачи можно фильтровать по компаниям, тегам и сложности. Советуем заходить сюда регулярно — и чтобы готовиться к интервью, и чтобы поддерживать навык решения задач. https://leetcode.com/problemset/algorithms/
#
#     Видеолекции Павла Маврина. Подойдут как для лучшего понимания тем из курса, так и для изучения новых, в том числе весьма продвинутых. https://www.youtube.com/c/pavelmavrin/videos
#
# Подготовка к интервью
# Здесь вы найдёте ресурсы, посвящённые подготовке к алгоритмическим собеседованиям.
#
#     Книга «Карьера программиста» или в оригинале “Cracking the Coding Interview”. Содержит много советов про подготовку к алгоритмическим собеседованиям. Будет полезна в дополнение к урокам 1 спринта нашего курса.
#
#     InterviewBit — другой хороший ресурс с задачами для собеседований. Не нужно возиться с фильтрами, можно пройти по всем интересующим темам. https://www.interviewbit.com/courses/programming/
#
#     Pramp — сервис для проведения peer-to-peer пробных интервью на английском языке. Вам назначается случайный человек в пару и вы собеседуете его, а потом он — вас. Очень полезно попробовать себя в роли не только собеседуемого, но и собеседущего — это поможет вам лучше почувствовать, как интервьюер оценивает кандидата. Очень рекомендуем в процессе подготовки к алгоритмическим интервью на английском языке. https://www.pramp.com/#/
#
#     Как проходят алгоритмические секции на собеседованиях в Яндекс — статья про подготовку к собеседованиям от Яндекса. https://habr.com/ru/company/yandex/blog/449890/
#
#     Вебинар «Открытое алгоритмическое собеседование». Можно посмотреть перед тем, как вы пойдёте на первое пробное интервью, чтобы прочувствовать формат в динамике. https://www.youtube.com/watch?v=aYuAd-IDigc
#
#     Coding Interview University — самый полный гайд по подготовке к собеседованиям. Настолько полный, что на его прохождение потребуется очень много времени: автор говорит о 8–12 часов в день в течение 8 месяцев. Поэтому оставляем его тут на случай, если вы настроены максимально решительно. https://github.com/jwasham/coding-interview-university
#
# Более академическое изучение
# Если вы хотите глубоко погрузиться в алгоритмы и структуры данных, то вам помогут следующие источники:
#
#     Книга «Алгоритмы. Построение и анализ» — классический труд по теории алгоритмов и структур данных. Много тем, включая математику, но большой объём и академический стиль изложения.
#
#     Codeforces — портал, посвящённый спортивному программированию. Мы рекомендуем его в контексте предыдущего пункта: тут вы сможете найти задачи на отработку тем, изученных в учебниках. https://codeforces.com/
#
# Где можно проявить себя
# Помимо подготовки можно поучаствовать в соревнованиях. Выиграть в них сложно, но зачастую прохождение в определённый раунд — это возможность попасть на радары рекрутеров топовых зарубежных компаний.
#
#     Google Code Jam — ежегодное соревнование от Google, проходит в несколько этапов от простых отборочных до финала с очень сложными задачами. Попадание в Round 2 даёт хорошие шансы на то, чтобы с вами связался рекрутер Google. Если вы студент, то рекомендуем также поучаствовать в более простом Kick Start. https://codingcompetitions.withgoogle.com/codejam https://codingcompetitions.withgoogle.com/kickstart
#
#     Facebook Hacker Cup — аналогичное соревнование от Facebook. https://www.facebook.com/hackercup
#
#     Yandex Cup — соревнование от Яндекса. В отличие от вышеперечисленных, проводится не только по алгоритмам, но и по другим направлениям. https://yandex.ru/cup/
#
#     Advent of Code — это не столько соревнование, сколько возможность порешать и обсудить задачи с друзьями или коллегами. https://adventofcode.com/
#
# Надеемся, что эти материалы вам пригодятся, и вы продолжите заниматься алгоритмами и после окончания нашего курса.

# %% [markdown]
# ## На собеседовании
# В завершение уроков про собеседования перечислим довольно очевидные, но важные моменты.
# Убедитесь, что во время собеседования вы будете находиться в комфортной обстановке и с хорошим интернетом. Обычно рекрутеры спрашивают, какое время вам будет удобно. Выбирайте такое, когда вас ничего не будет отвлекать. Лучше, если перед собеседованием у вас запланировано хотя бы несколько свободных минут, чтобы не бежать с рабочей встречи и не тратить драгоценное время.
# К старту собеседования у вас должны быть настроены камера и микрофон и выданы нужные разрешения. Если для звонка нужно установить программу — сделайте это заранее. Если у вас не получится принять звонок через неё, вам могут звонить на мобильный телефон, а это не всем удобно. Когда звонят из другой страны, качество связи может быть существенно хуже, чем через специализированные программы, авторы которых в последнее время сильно улучшили качество звука и видео. Это особенно критично, если вы будете общаться на языке, которым вы не владеете в совершенстве.
# Также нужно заранее подготовить бумагу с ручкой, на которой вы будете делать пометки и придумывать решение. Иногда кандидаты забывают это сделать, и тогда им приходится искать их прямо во время собеседования, из-за чего тратится время и создаётся лишний стресс.
# Наконец, не будет лишней и питьевая вода в зоне досягаемости. В отличие от обычного программирования, когда вы пишете код молча, на собеседовании нужно будет разговаривать с интервьюером.
# image
# Мы верим, что вы выспитесь перед интервью, подойдёте к нему в отличной форме, и у вас всё получится!
# А в нашем курсе остался финальный спринт, желаем вам успешно с ним справиться.
# Если вы хотите принять участие в пробном алгоритмическом собеседовании с наставником, пожалуйста, заполните форму. После этого мы с вами свяжемся и обсудим дальнейшие шаги.

# %% [markdown]
# <a id="tasks"></a>
# ## Задачи для подготовки
# [go back to title](#title)
#
# Ссылка на контекст: https://contest.yandex.ru/contest/34147/problems

# %% [markdown]
# <a id="A"></a>
# ### A. Card Counter
# [go back to the title](#title)
#
#     Язык 	Ограничение времени 	Ограничение памяти 	Ввод 	Вывод
#     Все языки 	0.25 секунд 	256Mb 	стандартный ввод или input.txt 	стандартный вывод или output.txt
#     Node.js 14.15.5 	1 секунда 	256Mb
#     Python 3.7.3 	1 секунда 	256Mb
#     OpenJDK Java 11 	0.5 секунд 	256Mb
#     OpenJDK Java 15 	0.5 секунд 	256Mb
#
# На стол в ряд выложены карточки, на каждой карточке написано натуральное число. За один ход разрешается взять карточку либо с левого, либо с правого конца ряда. Всего можно сделать k ходов. Итоговый счет равен сумме чисел на выбранных карточках. Определите, какой максимальный счет можно получить по итогам игры.
#
# Вы можете воспользоваться заготовками кода для данной задачи из репозитория курса
# ### Формат ввода
# В первой строке записано число карточек n (1≤n≤105).
#
# Во второй строке записано число ходов k (1≤k≤n).
#
# В третьей строке через пробел даны числа, записанные на карточках. i-е по счету число записано на i-й слева карточке. Все числа натуральные и не превосходят 104.
#
# ### Формат вывода
# Выведите единственное число —- максимальную сумму очков, которую можно набрать, сделав k ходов.
# ### Пример:
#     Ввод/Вывод
#
#     7
#     3
#     5 8 2 1 3 4 11
#
#     24
#
#     Ввод/Вывод
#
#     5
#     5
#     1 2 3 4 5
#
#     15
#
#     Ввод/Вывод
#
#     7
#     4
#     1 1 9 2 2 2 6
#
#     17

# %%
# code A
def max_sum(n, k, arr):
    if k == n:
        return sum(arr)
    else:
        _sum = sum(arr[0:k])
        max_sum = _sum
        for i in range(k):
            _sum = _sum - arr[k - i - 1] + arr[n - i - 1]
            if _sum > max_sum:
                max_sum = _sum
        return max_sum
            
if __name__ == '__main__':
    n = int(input())
    k = int(input())
    arr = list(map(int, input().split()))
    
    print(max_sum(n, k, arr))
# Out:
# 7
# 4
# 1 1 9 2 2 2 6
# 17

# %% [markdown]
# <a id="A"></a>
# ### B. Статус 200
# [go back to the title](#title)
#
# 	Все языки 	Python 3.7.3 	GNU c++17 7.3
#     Ограничение времени 	1 секунда 	2 секунды 	0.3 секунды
#     Ограничение памяти 	256Mb 	256Mb 	64Mb
#     Ввод 	стандартный ввод или input.txt
#     Вывод 	стандартный вывод или output.txt
#
# Вам дан массив натуральных чисел ai. Найдите число таких пар элементов (ai,aj), где ∣∣ai−aj∣∣%200==0 и i<j.
#
# Вы можете воспользоваться заготовками кода для данной задачи из репозитория курса.
# Формат ввода
# В первой строке дан размер массива n (1≤n≤200000 ).
#
# Во второй строке через пробел записаны элементы массива ai (1≤ai≤109).
# Формат вывода
# Выведите единственное число — количество пар, подходящих под указанное выше условие.
# Пример 1
# Ввод
# Вывод
#
# 5
# 203 404 204 200 403
#
#
#
# 2
#
# Пример 2
# Ввод
# Вывод
#
# 1
# 1000000
#
#
#
# 0
#
# Пример 3
# Ввод
# Вывод
#
# 3
# 2022 2020 2021
#
#
#
# 0
